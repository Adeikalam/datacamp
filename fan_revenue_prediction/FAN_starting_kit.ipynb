# %% [markdown]
# <div style="text-align: left;">
# <table style="width:100%; background-color:transparent;">
#   <tr style="background-color:transparent;">
#     <td style="background-color:transparent;"><a href="http://www.datascience-paris-saclay.fr">
# <img border="0" src="http://project.inria.fr/saclaycds/files/2017/02/logoUPSayPlusCDS_990.png" width="90%"> </td>
#      <td style="background-color:transparent;"><a href="https://www.sidetrade.com/">
# <img border="0" src="https://www.sidetrade.com/wp-content/uploads/22050384_10213210110060640_1095182809_o-300x117.png" width="60%"> </td>
#   </tr>
# </table>
# </div>
#
# <center><h1>FAN revenue prediction challenge</h1></center>
# <br/>
# <center>Lucy Liu (CDS), Maria Teleczuk (CDS), Clément Chastagnol (Sidetrade),<br /> Gael Varoquaux (Inria, Parietal), Alex Gramfort (Inria, Parietal), Guillaume Lemaitre (Scikit-learn @ Inria Foundation)</center>

# %% [markdown]
# Predicting revenue using French Attribution Notices: [RAMP studio challenge](https://ramp.studio/problems/fan_revenue_prediction)

# %% [markdown]
# ## Table of Contents
#
# 0. [Introduction](#Introduction)
# 1. [Data](#Data)
# 3. [Score metric](#Score-metric)
# 4. [Data exploration](#Data-exploration)
# 5. [Predictions](#Predictions)
# 6. [Record linkage](#Record-linkage)
# 7. [Submission structure](#Submission-structure)
# 8. [Local testing](#Local-testing-(before-submission))
# 9. [Submitting to RAMP studio](#Submitting-to-[ramp.studio](http://ramp.studio))
# 10. [More information](#More-information)

# %% [markdown]
# # Introduction
#
# The objective of this challenge is to work with 'dirty data'. Most real data is dirty and the availability of high-quality, open-source ML and data analysis frameworks (such as [scikit-learn](https://scikit-learn.org/),
# [pandas](https://pandas.pydata.org/)...) means that the next frontier for tooling and automation lies in preprocessing. This challenge aims to investigate methodologies to perform statistical analysis directly on the original dirty data.
#
# There are two datasets in this challenge:
#
# * `company_revenue_TRAIN.csv` - company revenue declarations.
# * `award_notices_RAMP.csv` -  French Attribution Notices.
#
# # Aim
#
# The predictive aim of this challenge is to use `company_revenue_TRAIN.csv` and `award_notices_RAMP.csv` to predict the Revenue for each entry in the 'company financial data' dataset. It is advised that you use both datasets, as it improves the prediction (see [Score comparison](#Score-comparison)), but using only the `company_revenue_TRAIN.csv` dataset is also allowed.

# %% [markdown]
# # Data
#
# ## Company financial data
#
# This dataset was built from an extract of the [National Institute of Statistics and Economic Studies (INSEE)](https://www.insee.fr/en/accueil) reference database of company revenue declarations from 2013 to 2018. Each row represents the declaration of one company for one year and the following information is provided in the columns:
#
# * `Legal_ID` - the reconcilled legal ID of the company
# * `Name` - the name of the company
# * `Activity_code (APE)` - 'Activite Principale de l'Entreprise', the main activity of the company - more information in [English](https://www.startbusinessinfrance.com/code-ape) or in [French](https://www.service-public.fr/professionnels-entreprises/vosdroits/F33050)
# * `Address`
# * `Zipcode`
# * `City`
# * `Revenue` - in Euros
# * `Headcount`
# * `Fiscal_year_end_date`
# * `Fiscal_year_duration_in_months`
# * `Year`
#
# There are a few things to note:
#
# * there are revenue declarations for the same company but different years
# * there is a large reduction in entries for the years 2017 and 2018 due to the Loi Macron law in 2017
# * the 'same company' can have several different entities, resulting in entries where the `Legal_ID` is different but the `Name`, `Address`, `City` and `Zipcode` are all the same.
# * `Revenue` can be negative. A negative revenue may be due to cancelled orders from the previous fiscal year that was recorded in the current fiscal year.
#
#
# ## Award notices
#
# Every French public organisation has to issue a call for tenders when buying supplies or services (above a minimum threshold). These are called public procurement contracts. Companies then compete anonymously on these contracts and when a bid is awarded, a notice has to be legally published by the public organization on the [BOAMP](https://www.boamp.fr/) (historical data is hosted by the [DILA](https://www.dila.premier-ministre.gouv.fr/)). These are called French Attribution Notices (FAN). About 25% of awards are actually electronically published.
#
# Each contract can be divided into a maximum of 5 lots and the same company can win >1 lot of a contract. The award notices dataset comprises award notices from 2017 and 2018. Each row refers to one lot and there can be up to 5 lots referring to the same contract. The following information is provided for each lot:
#
# * `ID_call` - ID of the award notice
# * `Publication_date` of the award notice
# * `End_of_call_date` of the award notice
# * `Departments_of_publication` - the department code(s) of the award notice
# * `Department_of_provision` - the department code(s) where the contract works/goods/services were provided
# * `Call_summary` - summary of the award notice
# * `Call_title` - title of the award notice
# * `Complete_call_description` - description of the award notice
# * `Total_amount` - total amount of the contract, from all lots, in euros
# * `CPV_classes` - Common Procurement Vocabulary (CPV), a classification system for public procurement used to describe the subject of procurement contracts (more information can be found [here](https://simap.ted.europa.eu/cpv))
# Columns providing details about the company issuing the contract:
# * `Buyer_name`
# * `Buyer_address`
# * `Buyer_zipcode`
# * `Buyer_city`
# * `Buyer_email`
# * `Buyer_URL`
#
# * `Contract_awarded` - whether or not the contact was awarded
#
# Columns providing details about the winner of each lot:
#
# * `ID` - unique lot ID
# * `awarded` - whether or not the contact was awarded
# * `description` - description of the lot
# * `incumbent_name` - name of the lot winnter
# * `incumbent_address` - address of the lot winner
# * `incumbent_zipcode` - zipcode of the lot winner
# * `incumbent_city` - city of the lot winner
# * `incumbent_country` - country of the lot winner
# * `number_of_received_bids` - number of bids this lot received
# * `amount` - amount of the lot in euros
#
# **Important notes**
#
# Both data sets are very dirty. There is a lot of missing data and the column descriptions provided above are a guide only. Further, the award notices dataset is much smaller than the company revenue declarations dataset. Therefore, it is expected that many companies in the company revenue declarations dataset are not present in the award notices dataset.
#
# ## Training and test
#
# The company revenue training dataset has been split into 'training' and 'test' subsets. The shapes are:
#
# * training: (1 495 948, 11)
# * test: (520 966, 11)
#
# Your model will be tested on a completely separate company revenue dataset stored on the RAMP server. This dataset has a shape of (702 181, 11). This test dataset will also be dirty but we can guarantee that the following columns will (only) be of numerical data type:
#
# * `Legal_ID`
# * `Headcount`
# * `Fiscal_year_duration_in_months`
# * `Year`

# %% [markdown]
# # Score metric
#
# A unique score is used:
#
# $$score =  |max(5,log_{10}(max(1,y\_true))) - max(5,log_{10}(max(1,y\_pred)))| $$
#
# Score interpretation:
#
# * A lower score is better
# * Any `y_true` or `y_pred` value less than 1 is 'taken' as 1
# * If both the `y_true` and `y_pred` are less than 100 000, the score would be 0.
# * The score is the same regardless of the order of `y_true` and `y_pred` in the equation.
# * If the difference in raw `y_true` and `y_pred` values is the same, the score is greater for smaller magnitudes of `y_true` and `y_pred`.

# %% [markdown]
# # Data exploration

# %%
# %matplotlib inline
import imp
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn

# %%
# !python download_data.py

# %% [markdown]
# ## Company financial data

# %%
from problem import get_train_data

X_df, y_array = get_train_data()

# %%
zip_dict['00']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-5085b100f651> in <module>
# ----> 1 zip_dict['00']
#
# KeyError: '00'

# %%
X_df.loc[X_df['Zipcode'] == 'na', 'Zipcode'] = X_df.loc[X_df['Zipcode'] == 'na', 'City'].apply(infer_zip)
X_df.loc[X_df['Zipcode'] == 'na', 'Zipcode'] = '00'

# %%
X_df.loc[X_df['Zipcode'] == 'na', 'Zipcode'] = '00'

# %%
X_df[X_df['Name'].isna()]
# Out:
#          Legal_ID Name Activity_code (APE)      Address Zipcode   City  \
# 889577  503771453  NaN               9609Z  25 RUE CAIL      75  PARIS
# 889578  503771453  NaN               9609Z  25 RUE CAIL      75  PARIS
# 889579  503771453  NaN               9609Z  25 RUE CAIL      75  PARIS
#
#         Headcount Fiscal_year_end_date  Fiscal_year_duration_in_months    Year
# 889577        NaN           2013-03-31                            12.0  2013.0
# 889578        NaN           2015-03-31                            12.0  2015.0
# 889579        NaN           2016-03-31                            12.0  2016.0

# %%
X_df.loc[X_df['Name'].isna(), 'Name'] = 'nan'

# %%
headcounts = X_df[['Name', 'Headcount']].groupby('Name').mean().fillna(0).to_dict()['Headcount']
names = X_df['Name'].values
heads = np.zeros(len(names))

for i,name in enumerate(names):
    if type(name) == type('a string'):
        heads[i] = headcounts[name]
    else:
        heads[i] = 0
    if i % 100000 == 0:
        print(i)
        
X_df['Headcount'] = heads

#for i,name in enumerate(X_df['Name'].values):
#    X_df.loc[i, 'Headcount'] = headcounts[name]
#    if i % 100 == 0:
#        print(i)
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000

# %%
X_df.drop(['APE'])
# Out:
#           Legal_ID                             Name Activity_code (APE)  \
# 0           582296                          COMICOB                 NaN
# 1           582981           CIANFARANI JEAN-MICHEL                 NaN
# 2           588541              OK POULET 5EME SARL                 NaN
# 3           589275  INSTITUT DE LA QUALITE S.A.R.L.                 NaN
# 4           592972                     EXPERT TRADE                 NaN
# ...            ...                              ...                 ...
# 1495943  987320355                      IBT CONCEPT               1812Z
# 1495944  995750288                           DAGARD               2825Z
# 1495945  995750288                           DAGARD               2825Z
# 1495946  995750288                           DAGARD               2825Z
# 1495947  995750288                           DAGARD               2825Z
#
#                                                    Address Zipcode     City  \
# 0                            BOULOUPARIS BP 15 BOULOUPARIS      00      NaN
# 1        33 AVENUE H. LAFLEUR - VICTOIRE - B.P. 4031 NO...      00      NaN
# 2                                         23 RUE PAUL BERT      98   NOUMEA
# 3        224 RUE J. IEKAWE - COMPLEXE DE LA BELLE-VIE -...      98   NOUMEA
# 4                       2 RUE DE L ASTROLABE OUEMO MAGENTA      98   NOUMEA
# ...                                                    ...     ...      ...
# 1495943                         56 CHEMIN DE SAINT BERNARD      64  BAYONNE
# 1495944                                                NaN      12  BOUSSAC
# 1495945                                                NaN      12  BOUSSAC
# 1495946                                                NaN      12  BOUSSAC
# 1495947                                                NaN      12  BOUSSAC
#
#          Headcount Fiscal_year_end_date  Fiscal_year_duration_in_months  \
# 0              0.0           2016-12-31                            12.0
# 1              0.0           2016-12-31                            12.0
# 2              1.0           2016-12-31                            12.0
# 3              0.0           2016-12-31                            12.0
# 4              0.0           2016-12-31                            12.0
# ...            ...                  ...                             ...
# 1495943        4.0           2016-12-31                            12.0
# 1495944      378.0           2013-12-31                            12.0
# 1495945      378.0           2014-01-31                            12.0
# 1495946      378.0           2014-12-31                            12.0
# 1495947      378.0           2015-12-31                            12.0
#
#            Year  HeadCount
# 0        2016.0        0.0
# 1        2016.0        0.0
# 2        2016.0        1.0
# 3        2016.0        0.0
# 4        2016.0        0.0
# ...         ...        ...
# 1495943  2016.0        4.0
# 1495944  2013.0      378.0
# 1495945  2014.0      378.0
# 1495946  2014.0      378.0
# 1495947  2015.0      378.0
#
# [1495948 rows x 11 columns]

# %%
names
# Out:
# array(['COMICOB', 'CIANFARANI JEAN-MICHEL', 'OK POULET 5EME SARL', ...,
#        'DAGARD', 'DAGARD', 'DAGARD'], dtype=object)

# %%
heads
# Out:
# array([  0.,   0.,   1., ..., 378., 378., 378.])

# %%
headcounts
# Out:
# {'#66#': 0.0,
#  '#CAP WELL CONSULTING': 0.0,
#  '#SCALENES': 0.0,
#  '#TERRITOIREDIGITAL': 0.0,
#  '& + SI AFFINITES...': 1.0,
#  '& COM X': 0.0,
#  '& DIEU CREA LA FEMME': 0.0,
#  '& FLORE & SENS': 13.0,
#  '& SENSCIEL': 0.0,
#  '&SPACES SARL': 0.0,
#  "''B P I'' BUSINESS - PRESTATIONS - INFORMATIQUE": 0.0,
#  "''ESPACES VERTS - JEAN CHARLES NAVE''": 3.0,
#  "''GEMME''": 4.0,
#  "''NSV COIFFURE''": 0.0,
#  "'CAUCHI DESIGN'": 6.5,
#  "'E.S.T.P'": 0.0,
#  "'ENTREPRISE GENERALE QUENTIN'.": 0.0,
#  "'FABRICATION MONTAGE TUYAUTERIES'": 0.0,
#  "'G7 ELECTRICITE'": 0.0,
#  "'GUIMAE'": 0.0,
#  "'L'ANTRE DE XAFI'": 0.0,
#  "'M.R.C.'": 2.0,
#  "'REAL-BAT'": 0.0,
#  "'SARL COMELEC 13": 0.0,
#  "'SUDANTOINE PLOMBERIE'": 0.0,
#  "'T GULLE GENOT": 0.0,
#  "'TRANS.A.M": 21.0,
#  '(GROUPE)  ASTEK': 191.0,
#  '(I.S.M) ISOLATION SAINTE MARIE': 1.0,
#  '(INNOVATION - TECHNOLOGIE - DEVELOPPEMENT) INTECDEV, ITD': 0.0,
#  '(IPC)-INDUSTRIAL POWER COOLING': 0.0,
#  '(J)': 0.0,
#  '(LA PARENTHESE) LIBRAIRIE': 4.0,
#  '(M & M PARIS). MISS MODE': 0.0,
#  '(O! DE LA DUNE': 0.0,
#  '(PI) INGENIERIE': 0.0,
#  '(SOCIETE PRIVEE) PRESTIGE SECURITE': 100.75,
#  '(TMF) TRANSPORTS MICHEL FRAGNER': 0.0,
#  '* LANCEY EQUITATION *': 0.0,
#  '*ASTROLAB': 0.0,
#  '+ 30 STUDIO DES BUTTES CHAUMONT': 0.0,
#  '+ 33 IMPORT - EXPORT': 3.0,
#  '+ AUTO COLLECTOR GARAGE': 0.0,
#  "+ D'ESPACES": 0.0,
#  '+ IMMO': 0.0,
#  "+ QU'UN JARDIN": 1.0,
#  '+ECCE+': 0.0,
#  "+Q'1 CREDIT": 0.0,
#  '- 96 B -': 0.0,
#  '- ROYER - LECONTE - CADIO - ARCHITECTES': 4.0,
#  '-D.B BATIMENT-': 0.0,
#  '-FINANCIERE LADEN': 0.0,
#  '-I.D.E.O.': 7.0,
#  '. STEP DANCE AND MUSIC .': 9.5,
#  '...KEEP DREAMING': 0.0,
#  '.COMM': 0.0,
#  '.G LA PROD': 0.0,
#  '.NETVLM': 0.0,
#  '.SERVICE. INTERIEUR. AGENCEMENT.': 0.0,
#  '0 SOUCI, 1 SERVICE POUR LA VIE': 3.3333333333333335,
#  "0'  STROMBOLI": 0.0,
#  '0,0': 0.0,
#  '01 ACTION PREMIERE': 1.6666666666666667,
#  '01 BUREAUTIQUE': 0.0,
#  '01 CONTROLE': 23.0,
#  '01 DIAG IMMO': 0.0,
#  '01 NETTIQUE SERVICES': 0.0,
#  '01 OENO-VITI': 0.0,
#  '01 PHOENIX INFORMATIQUE': 1.0,
#  '01 RENOVATION': 5.0,
#  '01 TECHNOLOGIES': 3.0,
#  '01-ARCHIVE': 0.0,
#  '01-EXCOR': 0.0,
#  '01-PLICIT': 0.0,
#  '01BOUTIQUE': 0.0,
#  '01FORMATIQUE': 0.0,
#  '01NET MAG': 26.0,
#  '01PROSHOP': 0.0,
#  '02 ANGLET': 33.333333333333336,
#  '02 ASSUR': 0.0,
#  '02 BESANCON': 14.0,
#  "02 COTE D'OPALE": 0.0,
#  "02 DIAG'IMMO": 0.0,
#  '02 ESTHET': 1.5,
#  '02 FONTAINEBLEAU - AVON': 19.333333333333332,
#  '02 FORME': 1.0,
#  '02 KID NORD YVELINES': 9.0,
#  "02 LYON PRESQU'ILE": 19.0,
#  '02 PARIS 15': 23.0,
#  '02 PEARL': 1.0,
#  '02 QUIMPER': 43.0,
#  '02 ST GERMAIN EN LAYE': 14.0,
#  '02L-TRAITEUR': 0.0,
#  '03 DB LA LOGISTIQUE DE LA FIBRE OPTIQUE': 2.0,
#  '04 DECORATION CLAIR LOGIS': 0.0,
#  '04 MOTOCULTURE': 1.0,
#  '04 NOVEMBRE 2008': 16.0,
#  '04 RECYCLAGE': 2.5,
#  '06 FERMETURES': 0.0,
#  '06 PISCINES': 0.0,
#  '07 LAB': 0.0,
#  '09 INVEST': 0.0,
#  '1 + 1 EXPERTISE': 0.0,
#  '1 + 1 PRODUCTION': 0.0,
#  '1 + EN PLUS': 4.0,
#  '1 - 2 - TOIT': 0.0,
#  '1 000 VOLTS': 0.0,
#  "1 2 3 C'EST PROP'.": 0.5,
#  '1 2 3 CONSEIL': 0.0,
#  '1 2 3 COUVRE TOIT': 0.0,
#  '1 2 3 CUISINES': 0.0,
#  '1 2 3 DOM': 1.0,
#  '1 2 3 ISOLATION': 1.0,
#  '1 2 3 PRESENCE SERVICES': 0.0,
#  '1 2 3 SERVICES A DOM': 30.0,
#  '1 2 3 SOLEIL': 2.0,
#  '1 2 3 UN TOIT': 0.0,
#  '1 2 IMPORT': 0.0,
#  '1 ANACHARSIS': 0.0,
#  '1 BIS AGENCE': 0.0,
#  '1 BLOW': 9.0,
#  '1 BLOW SERVICES': 0.0,
#  '1 CONCEPT ARCHITECTEURS': 0.0,
#  '1 DAY EXPRESS': 44.0,
#  '1 DAY EXPRESS 79': 1.0,
#  '1 DAY EXPRESS FRANCHISE': 0.0,
#  '1 DEPENDANT': 4.0,
#  '1 DESTOCK PISCINES': 1.0,
#  '1 ER CHOIX  VIANDE SERVICE': 0.0,
#  '1 ET 1000 NUITS': 1.0,
#  '1 FONET SERVICES': 0.0,
#  '1 G CONSULT': 0.0,
#  "1 KFE, L'ADDITION": 0.0,
#  '1 KM A PIEDS': 0.0,
#  '1 LIFE': 0.0,
#  '1 MONDE A PART': 0.0,
#  '1 P.M.': 0.0,
#  '1 PACT': 0.0,
#  '1 PACT EDUCATION': 0.0,
#  '1 PEC': 0.0,
#  '1 POINT 61 ARCHITECTURE': 0.0,
#  '1 POINT C TOUT': 0.0,
#  '1 PRIME': 0.0,
#  '1 PRO 2 PAL': 0.0,
#  '1 PULSION': 1.0,
#  '1 RDM': 0.0,
#  '1 RUE DU 4 SEPTEMBRE': 0.0,
#  '1 TEAM STUDIO': 0.0,
#  '1 TERIORS RENOV': 0.0,
#  '1 WEEK FLAT': 0.0,
#  '1&1 DATACENTER SAS': 3.0,
#  '1+04 CONSULTING': 0.0,
#  '1+1 PHOTOCOMPOSITION': 0.0,
#  '1, 2, 3 SOLEIL': 0.0,
#  '1, 2,3, ASSIETTE !': 0.0,
#  '1,2,3 MEDIA': 1.5,
#  '1,2,3 SOLEIL': 1.0,
#  "1,2,3 SUBSOL TECH'": 2.0,
#  '1,2,3...MAISON': 3.0,
#  '1,618 ADVISORS': 0.0,
#  '1-2-3 BIJOUX': 0.0,
#  '1-2-3 EXPERTISES': 0.3333333333333333,
#  '1-2-3 PIZZA': 8.5,
#  '1-2-3 SOLEIL': 0.0,
#  '1-PACT': 0.0,
#  '1-PEK': 11.0,
#  '1. SECURITE LEVAGE': 0.0,
#  '1.2.3 ASSISTANCE': 0.0,
#  '1.2.3 BABY': 0.0,
#  '1.2.3 CUISINES': 0.0,
#  '1.2.3 ENFANTS': 0.0,
#  '1.2.3 GAMES': 0.0,
#  '1.2.3 GOBELINS': 0.0,
#  '1.2.3 H P L D': 7.0,
#  '1.2.3 HABITAT': 1.0,
#  '1.2.3 J ARRIVE': 0.0,
#  '1.2.3 NETTOYAGE': 0.0,
#  '1.2.3 PAPIERS': 0.0,
#  '1.2.3 PAYSAGE': 0.0,
#  '1.2.3 PAYSAGE DERRIEN': 0.0,
#  '1.2.3. AMBULANCES': 0.0,
#  '1.2.3. C': 0.0,
#  '1.2.3. CONCEPT': 0.0,
#  '1.2.3. EDITIONS': 0.0,
#  '1.2.3. EVEIL': 0.0,
#  '1.2.3. PC': 0.0,
#  '1.2.3. PC SERVICES': 1.0,
#  '1.2.3. SOLEIL': 0.0,
#  '1.2.3. STYLMA EMBALLAGES': 13.0,
#  '1.2.3.SOLEIL': 1.0,
#  '1.85 FILMS': 0.0,
#  '1.ONE': 0.0,
#  '1/33 PRODUCTIONS': 0.0,
#  '10 : 15 PRODUCTIONS': 0.0,
#  '10 A CONSULTING': 3.6666666666666665,
#  '10 ACTIVITES': 8.5,
#  '10 MEDIAS': 10.0,
#  '10 MENTIONS EURL': 1.0,
#  '10 PLACE': 3.0,
#  '10 RUE DE CRIMEE': 0.0,
#  '10 TRY SUD': 0.0,
#  '10-VINS INVESTISSEMENT': 0.0,
#  "10.08 SCENARIO D'ARCHITECTE": 1.0,
#  '10.7 SARL': 1.0,
#  '10.8': 0.0,
#  '100  WATT': 0.0,
#  '100 % 2 ROUES': 0.0,
#  '100 % ARBITRES': 2.0,
#  '100 % BENNE': 0.0,
#  '100 % BOIS': 0.0,
#  '100 % BONS PLANS': 0.0,
#  "100 % DANSE : L'ECOLE": 1.0,
#  '100 % FORME ULIS': 0.0,
#  '100 % KAWA': 0.0,
#  '100 % LATINO': 1.6666666666666667,
#  '100 % LOC': 0.0,
#  '100 % MOTO': 0.0,
#  '100 % PLOEMEUR': 4.0,
#  '100 % PUR TRACTEUR': 0.0,
#  '100 % SERVICES PRO': 0.0,
#  '100 % SOI': 0.0,
#  '100 COURSES': 0.0,
#  "100 D'WICHS": 0.0,
#  '100 FACONS': 0.0,
#  '100 PASSEPORTS': 0.0,
#  '100 POUR 100': 0.0,
#  '100 POUR 100 2 ROUES': 5.0,
#  '100 POUR 100 MAGNIFIQUE': 0.0,
#  '100 SACS KML': 0.0,
#  "100 SASS'SERVICES": 0.0,
#  '100% CLIMATISATION': 0.0,
#  '100% COURTAGE': 0.0,
#  '100% DISTRIBUTION': 3.0,
#  '100% DRH': 0.0,
#  '100% EXPERTS': 0.0,
#  '100% FETE': 0.0,
#  '100% FLEXIBLE': 0.0,
#  '100% FORME POISSY': 0.0,
#  '100% FORME VERSAILLES': 0.0,
#  '100% PISCINES': 0.0,
#  '100% REMORQUES': 0.0,
#  '100% SCOOTERS': 0.0,
#  '100% SERVICES': 3.0,
#  '100%DISCOUNT': 0.0,
#  '100/100 GERARD & SEBASTIEN SAUSSEREAU': 0.0,
#  '1000 ACCESS': 0.0,
#  '1000 AUTOS': 2.0,
#  '1000 ET UN DESSERTS...': 5.0,
#  '1000 ET UNE PROPRIETES': 1.0,
#  '1000 IMMO': 0.0,
#  '1000 MILES RACING': 0.0,
#  '1000 SOLDES': 5.5,
#  '1000 TY SERVICES': 10.0,
#  '1000-ANNONCES': 0.0,
#  '1000-ID-100-C': 0.0,
#  '1000MERCIS': 205.75,
#  '1001 BUTTERFLIES REAL ESTATE': 0.0,
#  '1001 CLES IMMO.COM': 1.0,
#  '1001 COULEURS': 1.0,
#  '1001 CRECHES': 38.75,
#  '1001 CUISINES': 1.0,
#  '1001 ENTREPRISES': 0.0,
#  '1001 EXPERTISE': 0.0,
#  '1001 FENETRES': 0.0,
#  '1001 FEUILLES': 1.0,
#  '1001 FLEURS': 1.0,
#  '1001 INTERIMS': 0.0,
#  '1001 JARDINS': 0.0,
#  '1001 MACARONS': 0.0,
#  '1001 NEGOCE': 2.0,
#  '1001 PALETTES': 16.0,
#  '1001 PIXELS': 0.0,
#  '1001 PNEUS': 0.0,
#  '1001 SERVICES': 1.0,
#  '1001 TABLES SARL': 1.5,
#  '1001 TENTATIONS': 0.0,
#  '1001 TRANSPORT': 0.0,
#  '1001-BIENETRE': 0.0,
#  '1001BONBONS.FR': 0.0,
#  '100C': 1.0,
#  '100DRINE EDITION': 0.0,
#  '100EME ETAGE': 0.0,
#  '101 CONSULTING': 0.0,
#  '101 HAUSSMANN': 0.0,
#  '101 INFORMATIQUE': 0.0,
#  '101 SERVICES': 0.0,
#  '102 EQUIVOXE': 2.0,
#  '102 GRAPHIC': 0.0,
#  '105 DB': 2.0,
#  '105 EXPERTISES': 0.0,
#  '1064 IMPRESSION A CHAUD ET CREATION': 0.0,
#  '107 ARCHITECTURE': 1.0,
#  '109': 0.0,
#  '109 ARCHITECTES ET ASSOCIES': 2.0,
#  '109 COMMUNICATION': 0.0,
#  '109 COMPANY': 0.0,
#  '109 FILMS': 50.0,
#  '109 GRENELLE': 4.75,
#  '109 IMMOBILIER': 0.0,
#  '109 PARACHUTISME': 0.0,
#  '10MINUTES': 0.0,
#  '10NAMICRO': 2.0,
#  '10TORSIONS': 13.0,
#  '10VINS': 0.0,
#  '11 BIS': 0.0,
#  '11 CFM': 0.0,
#  '11 DELESTRAINT': 0.0,
#  '11 EME AVENUE': 0.0,
#  '11 EVENTS': 0.0,
#  '11 INDUSTRIE': 0.3333333333333333,
#  '11 MANAGEMENT': 0.0,
#  "11 RUE DE L' ECHELLE": 0.0,
#  '11/15 CONCEPT': 1.0,
#  '110 VIGNE': 8.666666666666666,
#  '111': 17.0,
#  '111 ETANCHEITE': 0.0,
#  '1111 ARCHITECTURE': 0.0,
#  '112 CARATS': 0.0,
#  '112 EDITIONS': 0.0,
#  '113 SAINT GERMAIN': 0.0,
#  '113JB CLEMENT': 0.0,
#  '114': 0.0,
#  '119 ROYAL CHICKEN': 1.0,
#  '11E ART': 7.0,
#  '11E DISTRICT': 1.0,
#  '11H11-ONZE HEURES ONZE': 0.0,
#  '12 AM': 0.0,
#  '12 ARCHITECTES': 0.0,
#  '12 AVENUE ARISTIDE BRIAND': 0.0,
#  '12 JOFFRE': 0.0,
#  '12 RESIDENCE SERVICES': 6.0,
#  '12/8 PRODUCTIONS': 0.0,
#  '120 FILMS': 0.0,
#  '120 GR': 0.0,
#  '120 JEAN JAURES': 0.0,
#  '120 X 125': 3.0,
#  '121 COURCELLES': 0.0,
#  '121 DIGITAL MEDIA': 0.0,
#  '121TRADING': 0.0,
#  '123 AUTOMOBILES': 1.0,
#  '123 CLOTURE': 0.0,
#  '123 MEDIA COMMUNICATION': 0.0,
#  '123 PAIE ON LINE': 9.0,
#  '123 SOLEIL': 0.0,
#  '123 TEST': 0.0,
#  '123 TRANSPORT - LOGISTIQUE': 0.0,
#  '123-INVEST': 0.0,
#  '123BILLETS': 15.25,
#  '123BOUTCHOU NETWORK': 0.0,
#  '123COMPTAONLINE': 0.0,
#  '123ENERGIE.MOTOCULTURE': 1.0,
#  '123IMPRIM': 0.0,
#  '123IT': 0.0,
#  '123PUB': 0.0,
#  '123RENDEMENT AUDIOVISUEL': 1.0,
#  '125 BAY': 0.0,
#  '126 MEDIA': 0.0,
#  '127 PARTICIPATION ET DEVELOPPEMENT': 0.0,
#  '12H25': 0.0,
#  '12HG': 0.0,
#  "13 A L'AISE": 0.0,
#  '13 A LA DOUZAINE': 1.0,
#  '13 ATTACHES RP ONLINE': 0.0,
#  '13 BIS': 2.0,
#  '13 COM': 1.0,
#  '13 CONSULTING': 0.0,
#  '13 EMBALLAGE DE LA COMMANDERIE': 0.0,
#  '13 EMBALLE': 0.0,
#  '13 HANDICAP ET SENIORS SERVICES PLUS': 0.0,
#  '13 IMPASSE DE LA FLAMBERE': 0.0,
#  '13 M AVENUE': 3.0,
#  '13 MENTHE BASILIC': 2.0,
#  '13 PASS MULTIMEDIA': 0.0,
#  '13 PRODUCTIONS': 10.333333333333334,
#  '13 PROVENCE TRANSPORTS': 1.0,
#  '13 QUAI DE SUFFREN': 0.0,
#  '13 TRANS': 0.0,
#  '13 VOLTS': 1.0,
#  '13/13': 0.0,
#  '130 VERSAILLES': 0.0,
#  '13000 TP': 0.0,
#  '1337 INVEST': 0.0,
#  '134 GAMBETTA': 0.0,
#  '134 TOCQUEVILLE': 1.0,
#  '1340 MOTORCYCLES': 0.0,
#  '135 24 R': 10.0,
#  '135 B': 0.0,
#  '135 WAGRAM': 0.0,
#  '136-INFORMATIQUE': 76.0,
#  '138, VILLA HUGO': 0.0,
#  '139 PAYSAGES': 0.0,
#  '13B CONCEPTION': 0.0,
#  '13B CONSTRUCTION': 2.5,
#  '13DECOEUR': 0.0,
#  '13EME AVENUE BY MARTINE COLOOS': 0.6666666666666666,
#  '13M INVEST': 0.0,
#  '13MARS PRODUCTION': 0.0,
#  '13TAXI': 0.0,
#  '14 AMBULANCES': 0.0,
#  "14 D'ERLON": 0.0,
#  '14 HEURES 30': 0.0,
#  '14 NEMOURS': 0.0,
#  '14 RUE DE LA PREMIERE ARMEE': 0.0,
#  '14 RUE RHIN ET DANUBE': 0.0,
#  '14 SEPTEMBRE': 21.0,
#  '1411': 0.0,
#  '143 PRODUCTIONS': 0.0,
#  '146EME AVENUE': 0.0,
#  '1492': 0.0,
#  '1492 PRODUCTIONS': 0.0,
#  '1492 SELECTION': 0.0,
#  '1492 STUDIO': 0.0,
#  '14MATIK': 0.0,
#  '15 ESPACE AMPERE': 0.0,
#  '15 K': 0.0,
#  '15 MATIGNON': 48.0,
#  '15 RUE DE FRANCE': 0.0,
#  '15-30 PUBLISHING': 0.0,
#  '1508': 0.0,
#  "154 RUE DE L'UNIVERSITE": 0.0,
#  '155 AVENUE': 0.0,
#  '15MARCHES': 0.0,
#  '16 ART': 0.0,
#  '16 ARTS PRODUCTION': 0.0,
#  '16 CARREFOUR JOUAUST': 0.0,
#  '16 CHALOTAIS': 0.0,
#  '16 INTERIM SUBSTITUTE RH': 0.0,
#  '16 PSTA COMPTOIR': 6.0,
#  "16'ELECT": 1.0,
#  '16-19 CORPORATE': 2.0,
#  '16-19 EVENTS': 5.333333333333333,
#  '1601 COIFFURE': 0.0,
#  '1609': 0.0,
#  '163 ATELIERS': 0.0,
#  '1630 CONSEIL': 9.0,
#  '1633 SERVICES': 0.0,
#  '163X': 2.0,
#  '164 ESBAR': 0.0,
#  '1672 HOUSE COFFEE': 0.0,
#  '169, ARCHITECTURE': 0.0,
#  '16EME': 6.0,
#  '16EME AVENUE': 2.0,
#  '16EME AVENUE COIFFURE': 0.0,
#  '16EME OUEST': 2.0,
#  '16PROD': 0.0,
#  '17': 0.0,
#  '17 EME AVENUE': 1.0,
#  '17 EXPERTISE': 9.2,
#  '17 JUIN FICTION': 0.0,
#  '17 JUIN MEDIA': 61.0,
#  '17 LOUIS GUERIN': 0.0,
#  '17 MARS': 10.0,
#  '17-8': 0.0,
#  '170 STYLES': 2.0,
#  '1706 CONSEIL': 0.0,
#  '1718': 0.0,
#  '1723': 0.0,
#  '1752 SIGNATURE VINS': 0.0,
#  '176 BOULEVARD': 0.0,
#  '1762 CONSULTANTS': 0.0,
#  '1788 CONSULTING': 0.0,
#  '1789': 0.0,
#  '18 AVRIL': 0.0,
#  '18 BRUMAIRE': 0.0,
#  '18 CHALOTAIS': 0.0,
#  '18 EDITIONS': 0.0,
#  '18 MARIGNAN': 0.0,
#  '18 PARMENTIER': 0.0,
#  "18 RUE D'ANJOU": 3.6666666666666665,
#  '18 SAINT MICHEL': 0.0,
#  '18&8 - MIL HUIT & HUIT': 0.0,
#  '180? (CENT QUATRE VINGT DEGRES)': 0.0,
#  '1810 VILLAGE': 0.0,
#  '1835': 0.0,
#  '1839 AND EVENTS': 0.0,
#  '1848': 0.0,
#  '1850 INVEST': 0.0,
#  '1850 PARFUM': 1.0,
#  '1856': 0.0,
#  '1864': 0.0,
#  '187 COM': 2.5,
#  '187 HALLAL FOOD': 7.0,
#  '1892 CORP': 1.0,
#  '18M': 0.0,
#  '18MARS': 1.0,
#  '19 ARCHITECTURE': 0.0,
#  '19 M CONSEIL': 0.0,
#  '19 PSTA TY ANNA': 6.0,
#  '19 RUE AUX OURS': 0.0,
#  '19.10 PROD': 0.0,
#  '1907 SARL': 0.0,
#  '1928': 2.0,
#  '1972': 0.0,
#  '1973': 0.0,
#  '1976': 0.0,
#  '1988 FILMS': 0.0,
#  '1997 MEDIA': 0.0,
#  '1A MACHINES ET INGENIERIE SPECIALES': 0.0,
#  '1AIN10SARL': 0.0,
#  '1BUTTON': 0.0,
#  '1C2F': 1.0,
#  '1CHR': 1.5,
#  '1CJP': 0.0,
#  '1D LAB': 0.0,
#  '1D RELATIONS MEDIA': 0.0,
#  '1D ZIK': 0.0,
#  '1DAY1EVENT': 0.0,
#  '1DIVIDED FILMS': 1.0,
#  '1ER MAI MEDICAL SERVICE': 13.0,
#  '1ER MEFFRE PATRIMOINE': 0.0,
#  '1ERE ETOILE': 1.0,
#  '1ERE GACHETTE': 0.0,
#  '1ERE LIGNE SECURITE PRIVEE': 46.0,
#  '1ERE VICTOIRE': 0.0,
#  '1ERES LIGNES': 0.0,
#  '1FOPRESTA': 0.0,
#  '1FORM TECHNOLOGIES': 0.0,
#  '1FORMACTION': 1.0,
#  '1FORMATIK': 0.0,
#  '1FOTEAM': 7.333333333333333,
#  '1G BAT': 0.0,
#  '1G-LINK CONSULTING': 0.0,
#  '1G6': 0.0,
#  '1GBTP': 1.0,
#  '1HOPE': 0.0,
#  '1K ENERGIE': 1.0,
#  '1MPLANT CERAM CONCEPT': 0.0,
#  '1NE PREMIERE': 0.0,
#  '1NGETUDE': 0.0,
#  '1NTERGROUPE': 0.0,
#  '1PACT ECO': 0.0,
#  '1PACT IMMO': 1.0,
#  '1PLUS1EQUALS3': 0.0,
#  '1PORTMODEL': 0.0,
#  '1PRIME SAS': 1.0,
#  '1PRIMEDOC': 0.0,
#  '1PULSE9': 0.0,
#  '1RDESIGN': 1.0,
#  '1ST DEMENAGEMENT': 0.0,
#  '1ST RENT CAR': 0.0,
#  '1TENDANCE': 1.0,
#  '1TERMED': 0.0,
#  '1TO1 INTERACTIVE': 0.0,
#  '1UNIVERS.NET': 0.0,
#  '1UP': 1.0,
#  '1VESTIM': 2.0,
#  '2 3C CONSEIL': 0.0,
#  '2 4 7 FILMS': 0.0,
#  '2 : PM ARCHITECTURES': 2.0,
#  '2 A 4': 0.0,
#  '2 A A': 0.0,
#  '2 A A Z': 1.0,
#  '2 A A Z BATI': 0.0,
#  '2 A ASSURANCES': 0.0,
#  '2 A AUDITORS': 0.0,
#  '2 A B D': 0.0,
#  '2 A BATI CONCEPT': 0.0,
#  '2 A C': 0.0,
#  '2 A CLIMATIQUE': 0.0,
#  '2 A CONSEILS': 2.0,
#  '2 A CREATION': 0.0,
#  '2 A DEPANNAGE': 0.0,
#  '2 A FINANCES': 0.0,
#  '2 A INGENIERIE': 0.0,
#  '2 A INVEST': 0.0,
#  '2 A RESTAURANTS': 15.0,
#  '2 A RESTAURATION': 0.0,
#  '2 A S': 0.0,
#  '2 A SERIGRAPHIE': 9.333333333333334,
#  '2 A SERVICES': 0.0,
#  '2 A SOLUTIONS': 0.0,
#  '2 A VITI': 0.0,
#  '2 A VOYAGES': 0.0,
#  '2 A.M.': 0.0,
#  '2 A.R.': 0.0,
#  '2 A.S.P. (AIDE ADMINISTRATIF SOCIAL ET PAIES)': 0.0,
#  '2 AA': 0.0,
#  '2 AB': 0.0,
#  '2 AB DIFFUSION': 1.5,
#  '2 AB PLUS': 1.0,
#  '2 ABC': 0.0,
#  '2 ABS': 0.0,
#  '2 AC': 0.0,
#  '2 ACP': 1.0,
#  '2 ADE': 0.0,
#  '2 ADF CONSEIL ET LOGICIELS': 0.0,
#  '2 ADR': 3.0,
#  '2 AE - AVEYRON AMENAGEMENT ELECTRICITE': 1.0,
#  '2 ALP CORDO': 0.0,
#  '2 ALX  PATRIMOINE': 1.0,
#  '2 AM OUVERTURE': 8.0,
#  '2 AMG': 1.0,
#  '2 AMP SECURITE PRIVEE': 0.0,
#  '2 AP': 0.0,
#  '2 ARES SERVICES': 0.0,
#  '2 AS': 1.0,
#  '2 B': 1.25,
#  '2 B & G QUALITE': 0.0,
#  '2 B 2 L': 0.0,
#  '2 B 2 P CONSEIL': 0.0,
#  '2 B ASSOCIES': 1.0,
#  '2 B C': 0.0,
#  '2 B COMTAL': 0.0,
#  '2 B CONCEPT': 0.0,
#  '2 B CONSEIL': 0.0,
#  '2 B CONSULTANT': 1.0,
#  '2 B CONSULTANTS': 0.0,
#  '2 B CONSULTING': 0.0,
#  '2 B DEVELOPPEMENT': 0.0,
#  '2 B ETANCHEITE': 0.0,
#  '2 B GRAPHIC': 0.0,
#  '2 B H H': 3.0,
#  '2 B IMMOBILIER': 1.0,
#  '2 B INVESTISSEMENT': 0.0,
#  '2 B LOMO': 0.0,
#  '2 B MENUISERIE': 1.5,
#  '2 B MIRAGE': 1.0,
#  '2 B PARTNERS': 1.75,
#  '2 B RECYCLAGE': 25.5,
#  '2 B REPRO': 1.0,
#  '2 B S BETIZEAU BATIMENT SERVICE': 4.0,
#  '2 B SERVICES': 2.0,
#  '2 B TRADUCTIONS': 0.0,
#  '2 B TRAVAUX': 0.25,
#  '2 BARS': 4.0,
#  '2 BAT': 0.0,
#  '2 BCG': 0.0,
#  '2 BCM': 2.3333333333333335,
#  '2 BD': 1.0,
#  '2 BDR': 10.0,
#  '2 BL': 0.0,
#  '2 BS': 1.0,
#  '2 BSI': 0.0,
#  '2 BTP': 0.0,
#  '2 BUFFA': 0.0,
#  '2 C': 0.0,
#  '2 C A': 0.0,
#  '2 C B': 16.5,
#  '2 C FACADES': 0.0,
#  '2 C FINANCE': 0.0,
#  '2 C I': 0.0,
#  '2 C INFORMATIQUE': 0.0,
#  '2 C L M': 0.0,
#  '2 C MECA': 0.0,
#  '2 C O IMMO': 0.0,
#  '2 C P': 15.666666666666666,
#  '2 C POMPAGE': 0.0,
#  '2 C.A.R.A. PARTICIPATIONS': 0.0,
#  '2 C.L.R.': 0.0,
#  '2 CA': 0.0,
#  '2 CAGALIN': 0.0,
#  '2 CAPS CONTROLE': 0.0,
#  '2 CAPS ENVIRONNEMENT': 0.0,
#  '2 CAPS SANTE': 0.0,
#  '2 CAUSE A EFFET': 0.0,
#  '2 CE': 2.0,
#  '2 CFR': 0.0,
#  '2 CO': 3.0,
#  '2 CORDES A CORDES': 0.0,
#  '2 CP BEUVRY': 0.0,
#  '2 CR': 0.0,
#  '2 CV EXPERIENCE.COM': 1.0,
#  "2 D 2 DETARTRAGE DEBOURBAGE ECONOMIE D'ENERGIE": 1.0,
#  '2 D 2 M': 0.0,
#  '2 D CONSULTANTS': 0.0,
#  '2 D GRAPHIC': 3.0,
#  '2 D INVESTISSEMENTS': 1.5,
#  '2 D.P. SERVICES': 0.0,
#  '2 DB IMMO': 0.0,
#  '2 DECO': 0.0,
#  '2 DG': 8.5,
#  '2 DI': 0.0,
#  '2 DOM': 0.0,
#  '2 DS': 1.0,
#  '2 DSM ADOUR': 0.0,
#  '2 DTI': 0.0,
#  '2 E F HOLDING': 0.0,
#  '2 EASY GROUP': 0.0,
#  '2 ECO - FERMETURES MENUISERIES ET HABITAT': 0.0,
#  '2 EF ELECTRICITE ENVIRONNEMENT FROID': 0.6666666666666666,
#  '2 ELEC': 0.0,
#  '2 ELT ENTREPRISE ELECTRICITE LAPARADE THIERRY': 0.0,
#  '2 ES NORD': 31.0,
#  '2 ET 2 CONSEILS': 0.0,
#  '2 F': 0.0,
#  '2 F 2 G': 4.75,
#  '2 F EMBALLAGES': 0.0,
#  '2 F I SYSTEMES': 5.0,
#  '2 F IMAGE': 3.0,
#  '2 F INVESTISSEMENTS': 0.0,
#  '2 F TECHNOLOGIES': 0.0,
#  '2 F.P.': 1.0,
#  '2 FAE': 0.0,
#  '2 FK CONSULTING S.A.S.': 0.0,
#  '2 FL ELECTRO': 1.0,
#  '2 FLG': 0.0,
#  '2 FLORES STUDIO': 1.0,
#  '2 FOIS 8': 2.75,
#  '2 FONTAINES': 0.0,
#  '2 FSR': 0.0,
#  '2 G': 7.5,
#  '2 G C A GROUPE GRAPHIQUE COMMUNICATION AUDIOVI- SUELLE - 2GCA -': 0.0,
#  '2 G CONSEIL': 0.0,
#  '2 G CONSTRUCTION': 6.0,
#  '2 G DIFFUSIONS': 0.0,
#  '2 G HOME': 0.0,
#  '2 G I': 0.0,
#  '2 G IMMO': 0.0,
#  '2 G IMMOBILIER': 0.0,
#  '2 G R C': 4.0,
#  '2 G RESTAURATION': 0.0,
#  '2 G SERVICES': 1.0,
#  '2 G.B.S.': 0.0,
#  '2 GM FINANCE': 0.0,
#  '2 GR': 0.0,
#  '2 H ARCHITECTURE': 2.0,
#  '2 H CONSTRUCTIONS': 0.75,
#  '2 H CONSULTING': 0.0,
#  '2 H DISTRIBUTION': 0.0,
#  '2 H GESTION IMMO': 0.0,
#  '2 HABUDZIK DURAN': 4.0,
#  '2 HAND CAR': 0.0,
#  '2 HARD': 0.0,
#  '2 HCP INVESTISSEMENTS': 1.0,
#  '2 HMHP': 0.0,
#  '2 HPS HOLDING': 0.0,
#  '2 HS CONSULTANTS': 2.0,
#  '2 I - INTER INVESTISSEMENTS': 44.5,
#  '2 I 010': 99.0,
#  '2 I 050': 2.0,
#  '2 I T INVESTISSEMENT INNOVATION': 0.0,
#  '2 I-F': 5.0,
#  '2 I.D': 0.0,
#  '2 I.S.M.': 0.0,
#  '2 IDO': 0.0,
#  "2 IE INGENIERIE ET EQUIPEMENT POUR L'IRRIGATION": 0.0,
#  '2 J': 0.0,
#  '2 J COM': 1.0,
#  '2 J CONSTRUCTION': 4.0,
#  '2 J DENTAIRES': 4.5,
#  '2 J DEVELOPPEMENT': 0.0,
#  '2 J FERMETURES': 0.0,
#  '2 J IMMO INVEST': 0.0,
#  '2 J INVESTISSEMENTS': 0.0,
#  '2 J P': 0.0,
#  '2 J TAXI': 0.0,
#  '2 J.M': 0.0,
#  '2 JCODF': 0.0,
#  '2 JF OPTIC AUDIO': 0.0,
#  '2 JL': 0.0,
#  '2 JL A': 0.0,
#  '2 JM': 0.0,
#  '2 JP': 2.5,
#  '2 JPE SPORTS': 3.0,
#  '2 JUIN': 0.0,
#  '2 KI SERVICES': 0.0,
#  '2 KL FORMATIONS': 0.0,
#  '2 L BAT': 0.0,
#  '2 L BATIMENT': 0.0,
#  '2 L C INFORMATIQUE': 3.0,
#  '2 L COMMUNICATIONS': 0.0,
#  '2 L CONCEPT': 0.0,
#  '2 L CONSTRUCTION': 0.0,
#  '2 L ELECTRIQUE': 1.0,
#  '2 L FINANCE': 0.0,
#  "2 L INNOV'": 0.0,
#  '2 L M': 5.0,
#  '2 L ORGANISATION': 0.0,
#  '2 L S TRANSPORTS': 0.0,
#  '2 L SOLUTIONS SAS': 0.0,
#  '2 L TOITURE': 2.0,
#  "2 L' SERVICE ARCHITECTURE": 0.0,
#  '2 L.C.M': 0.0,
#  '2 L.H.': 3.0,
#  '2 L.V INVEST': 0.0,
#  '2 LA': 0.0,
#  '2 LA VIBE RECORDS': 0.0,
#  '2 LG-TRANSPORT': 0.0,
#  '2 LINES': 2.0,
#  '2 LOUIS STRUCTURES': 0.0,
#  '2 M': 13.6,
#  '2 M 2 C': 0.0,
#  '2 M ALU': 0.0,
#  '2 M ASSUR': 0.0,
#  '2 M ASSURANCES': 0.0,
#  '2 M AUTOS EURL': 0.0,
#  '2 M B.ET': 2.0,
#  '2 M BEACH': 0.0,
#  '2 M CREATION': 0.0,
#  '2 M DIFFUSION': 0.0,
#  '2 M DISTRIBUTION': 0.0,
#  '2 M E': 1.0,
#  '2 M ELEC': 0.0,
#  '2 M EXPERTISES': 0.0,
#  '2 M INVEST': 1.0,
#  '2 M MEDIAS': 0.0,
#  '2 M NETTOYAGE': 45.666666666666664,
#  '2 M PAYSAGES': 1.0,
#  '2 M PRIMEURS': 0.0,
#  '2 M PROMOTION': 0.0,
#  '2 M RENOVATION': 0.0,
#  '2 M. INTERNATIONAL': 0.0,
#  '2 M.A.I': 9.0,
#  '2 M.C.': 0.0,
#  '2 M.T.S': 1.0,
#  '2 MA PLAST': 5.5,
#  '2 MANY PRODUCTIONS': 0.0,
#  '2 MARS': 0.0,
#  '2 MB FINANCES': 0.0,
#  '2 MC': 0.0,
#  '2 MC 2': 0.0,
#  '2 MC OPTIQUE': 0.0,
#  '2 MCL': 0.0,
#  '2 MCP': 21.0,
#  '2 MD': 0.0,
#  '2 MDDI CONSEILS': 0.0,
#  '2 MG ETUDES': 0.0,
#  '2 MGP SPORT ET DETENTE': 0.0,
#  '2 MINUTES': 0.0,
#  '2 MINUTES ANIMATION': 0.0,
#  '2 MJH': 0.0,
#  '2 MLC': 0.0,
#  '2 MO TRANSPORTS': 0.0,
#  '2 MORO': 0.0,
#  '2 MP': 0.0,
#  '2 MPG': 2.0,
#  '2 MT': 3.0,
#  '2 MTP': 0.0,
#  '2 MVP': 0.0,
#  '2 N INTERNATIONALE': 0.0,
#  '2 NA': 1.0,
#  '2 NH': 5.0,
#  '2 P': 0.0,
#  '2 P CONCEPTS': 0.0,
#  '2 P CONSEIL': 0.0,
#  '2 P CONSEILS': 0.0,
#  '2 P I': 0.0,
#  '2 P MENUISERIE': 0.0,
#  '2 P SO': 3.0,
#  '2 P.L.A.': 0.0,
#  '2 PA': 0.0,
#  '2 PA MACONNERIE GENERALE': 0.0,
#  '2 PCJ': 9.0,
#  '2 PEIRERA FACADES BORDELAISES': 0.0,
#  '2 PIR': 0.0,
#  '2 PLOMBERIE ELECTRICITE': 2.0,
#  '2 PM POIZAT MENUISERIE': 0.0,
#  '2 PMA': 1.3333333333333333,
#  '2 POLES VOYAGES': 1.0,
#  '2 POUR EMBALLER': 0.0,
#  '2 PRINT': 0.0,
#  '2 PROD': 0.0,
#  '2 PROTECTION INCENDIE': 3.75,
#  '2 R': 0.0,
#  '2 R COIFFURE': 0.0,
#  '2 R COMMERCIALISATION DISTRIBUTION': 0.0,
#  '2 R CONCEPTION': 0.0,
#  '2 R DE JARDIN': 1.0,
#  '2 R DE VIENNE': 0.0,
#  '2 R FINANCES': 8.0,
#  '2 R I': 2.0,
#  '2 R INFORMATIQUE': 38.0,
#  '2 R PROCESS': 4.5,
#  '2 R PROMOTION': 0.0,
#  '2 R R T.P': 0.0,
#  '2 RC': 0.0,
#  '2 RC CONSULT': 5.75,
#  '2 RD': 4.0,
#  '2 RIVES CONSEIL': 1.0,
#  '2 RL': 0.0,
#  '2 ROOS': 1.0,
#  '2 ROUES LOISIRS SCOOTER LOISIRS': 1.0,
#  '2 ROUES MOTOCULTURE': 0.0,
#  '2 ROUES SERVICE': 0.0,
#  '2 ROUES SERVICES': 0.0,
#  '2 ROUVRAY AUDIT ET CONSEIL': 0.0,
#  '2 RS': 0.0,
#  '2 RUE DIEUDONNE COSTES SAS': 64.0,
#  '2 S': 0.0,
#  '2 S - COMPUTING': 0.0,
#  '2 S COSMETIQUE': 6.0,
#  '2 S ELEC': 0.0,
#  '2 S IMMO': 0.0,
#  '2 S IMMOBILIER': 0.0,
#  '2 S INVEST': 0.0,
#  '2 S P H SENIOR SERVICES': 9.0,
#  '2 S USINAGE': 0.0,
#  '2 SAJT': 2.0,
#  '2 SEG': 0.0,
#  '2 SEVRIENNE SERVICE': 46.0,
#  '2 SPEE': 0.0,
#  '2 SPI': 0.0,
#  '2 SPOT DIGITAL FRANCE': 0.0,
#  '2 ST SOCIETE DES TECHNIQUES DE SECURITE ET DE TELECOMMUNICATION': 1.0,
#  "2 STEPH'S": 6.333333333333333,
#  '2 STI': 2.6666666666666665,
#  '2 SUN': 0.0,
#  '2 SVTP': 2.5,
#  '2 T 46': 0.0,
#  '2 T IMMOBILIER': 2.0,
#  '2 T MENUISERIE EBENISTERIE SARL': 1.8,
#  '2 THERMIE': 2.0,
#  '2 TMC - DAMON': 0.0,
#  '2 TORRENTS': 0.0,
#  '2 TOVO': 0.0,
#  '2 V': 0.0,
#  '2 V MENUISERIE': 11.0,
#  '2 VIENS STAR': 1.0,
#  '2 VL TEXTILE': 1.0,
#  '2 WF': 4.0,
#  '2 WHEELS PROMOTION': 0.0,
#  '2 X PLUS': 0.0,
#  '2 XM': 0.0,
#  '2 YS': 0.0,
#  '2 Z': 0.0,
#  '2 ZEROS 93 PUBLISHING': 0.0,
#  '2% IMMO': 0.0,
#  "2'BA NETT": 1.0,
#  '2,39 PRODUCTIONS': 0.0,
#  '2-28': 2.0,
#  '2-A': 1.0,
#  '2-B': 0.0,
#  '2-FIFTY-5 FRANCE': 0.0,
#  '2-FODIS': 1.0,
#  '2-LACS PLASTURGIE': 0.0,
#  '2-ZIK PRODUCTIONS': 0.0,
#  '2. A.V.E.': 0.0,
#  '2.14 TERRASSEMENTS': 0.0,
#  '2.16': 0.0,
#  '2.A': 6.0,
#  '2.A.H. ESPACE MEUBLE ET RENOVATION IMMOBILIER': 0.0,
#  '2.A.L': 0.0,
#  '2.A.P.L.S.': 0.0,
#  '2.B COMPTA': 0.0,
#  '2.B.O. LAVAGE': 0.0,
#  '2.C.2.A.': 0.0,
#  '2.C.E CONCEPT CUISINE ENVIRONNEMENT': 0.0,
#  '2.C.S': 0.0,
#  '2.D.A': 0.0,
#  '2.D.P': 0.0,
#  '2.E.M.D.': 0.0,
#  '2.F.': 0.0,
#  '2.F.P.R': 0.0,
#  '2.M. FINANCES': 5.0,
#  '2.M.I.': 0.0,
#  '2.M.O.T. ASCENSEURS DIFFUSION': 0.0,
#  '2.P.2.L.': 0.0,
#  '2.P.A': 0.0,
#  '2.P.R. INGENIERIE': 1.6,
#  '2.R.E.C.A': 0.0,
#  '2.R.J.': 1.0,
#  '2.S.B.': 1.0,
#  '2/4 BOULEVARD HAUSSMANN': 0.0,
#  '20 000 SAVEURS': 3.0,
#  '20 20 TECHNOLOGIES': 38.666666666666664,
#  '20 > 80 CONSULTING & COACHING': 0.0,
#  '20 BIS SAINT MICHEL': 0.0,
#  '20 DE REVE': 0.0,
#  '20 RECYCLAGE': 0.0,
#  '20 SUR 20 ADOM': 0.0,
#  '2000': 1.0,
#  '2000 CADRES ET IDEES': 1.0,
#  '2001 COMMUNICATION': 0.0,
#  '2001 PRODUCTIONS': 0.0,
#  '2006 SARL': 0.0,
#  '2007 PANDA FINANCE 1': 0.0,
#  '2007 PANDA FINANCE 2': 0.0,
#  '2008 PANDA FINANCE 11': 0.0,
#  '2008 PANDA FINANCE 3': 0.0,
#  '2009 KOALA FINANCE - MSN 36744': 0.0,
#  '2009 KOALA FINANCE - MSN 3766': 0.0,
#  '2009 KOALA FINANCE - MSN 3806': 0.0,
#  '2009 KOALA FINANCE- MSN 36743': 0.0,
#  '2010': 0.0,
#  '2012': 0.0,
#  '2014NATURE': 0.0,
#  '2015-RIVIERA-CEGIM': 0.0,
#  '2017': 0.0,
#  '2018': 0.0,
#  '202': 0.0,
#  '202 ECOMMERCE': 0.0,
#  '2020ENERGY': 0.0,
#  '205 CORP.': 0.6666666666666666,
#  '20BE': 0.0,
#  '21 BLANCHE': 0.0,
#  '21 BOULEVARD': 12.0,
#  '21 CONSTRUCTION': 0.0,
#  '21 EME PRODUCTION': 0.0,
#  '21 LUNES': 0.0,
#  '21 MARS': 0.0,
#  '21 PANNEAUX SOLAIRES': 2.0,
#  "21 RUE DE LA VILLE L'EVEQUE": 0.0,
#  '212 AUTO': 0.0,
#  '213 COMMUNICATION': 0.0,
#  '214 MISTRAL': 0.0,
#  '2170': 4.0,
#  '219 CONSULTING': 0.0,
#  '21CROISSANTS': 1.0,
#  '21JUIN DESIGN': 1.0,
#  '21TH AVENUE': 9.0,
#  ...}

# %%
headcounts.loc['ZZM', 'Headcount']
# Out:
# 0.0

# %%
X_df.loc[0,'Headcount']
# Out:
# nan

# %%
X_df['Name'].values
# Out:
# array(['COMICOB', 'CIANFARANI JEAN-MICHEL', 'OK POULET 5EME SARL', ...,
#        'DAGARD', 'DAGARD', 'DAGARD'], dtype=object)

# %%
list(set(['PARIS', 'PARIS', 'BOULOGNE']))
# Out:
# ['BOULOGNE', 'PARIS']

# %%
X_df[['Zipcode','City']].iloc[0:10].apply(test_func)
# Out:
# 0    na
# 1    na
# 2    98
# 3    98
# 4    98
# 5    98
# 6    98
# 7    98
# 8    98
# 9    98
# Name: Zipcode, dtype: object
# 0       NaN
# 1       NaN
# 2    NOUMEA
# 3    NOUMEA
# 4    NOUMEA
# 5    NOUMEA
# 6    NOUMEA
# 7    NOUMEA
# 8    NOUMEA
# 9    NOUMEA
# Name: City, dtype: object
# Zipcode    None
# City       None
# dtype: object

# %%
X_df['Zipcode'] = X_df['Zipcode'].astype('str').apply(lambda x: x[:2])
city_names = X_df[['Zipcode', 'City']].groupby('Zipcode').City.apply(list).values
zipcodes = X_df[['Zipcode', 'City']].groupby('Zipcode').City.apply(list).index
zip_dict = {zipcode:list(set(cities)) for zipcode,cities in zip(zipcodes, city_names)}

#remove nans 

for key in zip_dict.keys():
    for i, city in enumerate(zip_dict[key]):
        if type(city) != type('a string'):
            zip_dict[key].pop(i)

# %%
l.remove(math.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-6ba5d1a1a91f> in <module>
# ----> 1 l.remove(math.nan)
#
# ValueError: list.remove(x): x not in list

# %%
float('nan')
# Out:
# nan

# %%
def infer_zip(city):
    for key in zip_dict:
        if city in zip_dict[key]:
            return key

# %%
X_df[['Zipcode', 'City']].groupby('Zipcode').City.apply(list)
# Out:
# Zipcode
# 10    [FEUGES, FEUGES, FEUGES, FEUGES, MESGRIGNY, ME...
# 11    [NIEVROZ, NIEVROZ, NIEVROZ, NIEVROZ, CASTELNAU...
# 12    [CAPDENAC GARE, CAPDENAC GARE, CAPDENAC GARE, ...
# 13    [LAMBESC, LAMBESC, LAMBESC, LAMBESC, MARSEILLE...
# 14    [COLOMBELLES, COLOMBELLES, COLOMBELLES, COLOMB...
#                             ...
# 96    [LAROQUE D OLMES, LAROQUE D OLMES, LAROQUE D'O...
# 97    [SAVERDUN, SAVERDUN, SAVERDUN, SAVERDUN, SAVER...
# 98    [NOUMEA, NOUMEA, NOUMEA, NOUMEA, NOUMEA, NOUME...
# 99                                       [ROSES, ROSES]
# na    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Name: City, Length: 92, dtype: object

# %%
X_df[X_df['Zipcode'] == 'na']['City'].notna().mean()
# Out:
# 0.9982486516607957

# %%
X_df[X_df['City'].isna()]
# Out:
#           Legal_ID                                               Name  \
# 0           582296                                            COMICOB
# 1           582981                             CIANFARANI JEAN-MICHEL
# 11          608349  GALINIE ETUDES MAITRISES D'OEUVRE CONSEILS EXP...
# 13          608950                         TRANSPORTS CAMUSARD NATRAL
# 17          617613                                       ON THE BEACH
# ...            ...                                                ...
# 1491539  524789096                    HANSEN INDUSTRIAL TRANSMISSIONS
# 1491540  524789096                    HANSEN INDUSTRIAL TRANSMISSIONS
# 1494783  791953722                     LES FLOTS DE TROUVILLE LIMITED
# 1495769  810420711                            DOMINIQUE TANDE LIMITED
# 1495771  810420711                            DOMINIQUE TANDE LIMITED
#
#         Activity_code (APE)  \
# 0                       NaN
# 1                       NaN
# 11                      NaN
# 13                      NaN
# 17                      NaN
# ...                     ...
# 1491539               6420Z
# 1491540               6420Z
# 1494783               4781Z
# 1495769               8690F
# 1495771               8690F
#
#                                                    Address  Zipcode City  \
# 0                            BOULOUPARIS BP 15 BOULOUPARIS      NaN  NaN
# 1        33 AVENUE H. LAFLEUR - VICTOIRE - B.P. 4031 NO...      NaN  NaN
# 11       7 RUE DU CAPITAINE PERRAUD - FAUBOURG BLANCHOT...      NaN  NaN
# 13                     18 RUE SAINT ANTOINE - NUMBO NOUMEA      NaN  NaN
# 17       27 PROMENADE PIERRE VERNIER - COTE BLANCHE NOUMEA      NaN  NaN
# ...                                                    ...      ...  ...
# 1491539                                                NaN      NaN  NaN
# 1491540                                                NaN      NaN  NaN
# 1494783                                                NaN      NaN  NaN
# 1495769                     1 PALK STREET TORQUAY TQ 2 5EL      NaN  NaN
# 1495771                     1 PALK STREET TORQUAY TQ 2 5EL      NaN  NaN
#
#          Headcount Fiscal_year_end_date  Fiscal_year_duration_in_months  \
# 0              NaN           2016-12-31                            12.0
# 1              NaN           2016-12-31                            12.0
# 11             3.0           2016-12-31                            12.0
# 13             NaN           2016-12-31                            12.0
# 17            10.0           2016-12-31                            12.0
# ...            ...                  ...                             ...
# 1491539        NaN           2016-03-31                            12.0
# 1491540        NaN           2016-12-31                            12.0
# 1494783        NaN           2015-03-31                            12.0
# 1495769        NaN           2015-12-31                            12.0
# 1495771        NaN           2016-12-31                            12.0
#
#            Year
# 0        2016.0
# 1        2016.0
# 11       2016.0
# 13       2016.0
# 17       2016.0
# ...         ...
# 1491539  2016.0
# 1491540  2016.0
# 1494783  2015.0
# 1495769  2015.0
# 1495771  2016.0
#
# [468 rows x 10 columns]

# %%
y_array.shape
# Out:
# (1495948,)

# %%
X_df['Zipcode'].isna().mean()
# Out:
# 0.16794367183886072

# %%
X_df
# Out:
#           Legal_ID                             Name Activity_code (APE)  \
# 0           582296                          COMICOB                 NaN
# 1           582981           CIANFARANI JEAN-MICHEL                 NaN
# 2           588541              OK POULET 5EME SARL                 NaN
# 3           589275  INSTITUT DE LA QUALITE S.A.R.L.                 NaN
# 4           592972                     EXPERT TRADE                 NaN
# ...            ...                              ...                 ...
# 1495943  987320355                      IBT CONCEPT               1812Z
# 1495944  995750288                           DAGARD               2825Z
# 1495945  995750288                           DAGARD               2825Z
# 1495946  995750288                           DAGARD               2825Z
# 1495947  995750288                           DAGARD               2825Z
#
#                                                    Address  Zipcode     City  \
# 0                            BOULOUPARIS BP 15 BOULOUPARIS      NaN      NaN
# 1        33 AVENUE H. LAFLEUR - VICTOIRE - B.P. 4031 NO...      NaN      NaN
# 2                                         23 RUE PAUL BERT  98800.0   NOUMEA
# 3        224 RUE J. IEKAWE - COMPLEXE DE LA BELLE-VIE -...  98800.0   NOUMEA
# 4                       2 RUE DE L ASTROLABE OUEMO MAGENTA  98800.0   NOUMEA
# ...                                                    ...      ...      ...
# 1495943                         56 CHEMIN DE SAINT BERNARD  64100.0  BAYONNE
# 1495944                                                NaN      NaN  BOUSSAC
# 1495945                                                NaN      NaN  BOUSSAC
# 1495946                                                NaN      NaN  BOUSSAC
# 1495947                                                NaN      NaN  BOUSSAC
#
#          Headcount Fiscal_year_end_date  Fiscal_year_duration_in_months  \
# 0              NaN           2016-12-31                            12.0
# 1              NaN           2016-12-31                            12.0
# 2              1.0           2016-12-31                            12.0
# 3              NaN           2016-12-31                            12.0
# 4              NaN           2016-12-31                            12.0
# ...            ...                  ...                             ...
# 1495943        NaN           2016-12-31                            12.0
# 1495944        NaN           2013-12-31                            12.0
# 1495945        NaN           2014-01-31                            12.0
# 1495946      384.0           2014-12-31                            12.0
# 1495947      372.0           2015-12-31                            12.0
#
#            Year
# 0        2016.0
# 1        2016.0
# 2        2016.0
# 3        2016.0
# 4        2016.0
# ...         ...
# 1495943  2016.0
# 1495944  2013.0
# 1495945  2014.0
# 1495946  2014.0
# 1495947  2015.0
#
# [1495948 rows x 10 columns]

# %%
X_df.groupby('Name').sum()
# Out:
#                                      Legal_ID   Zipcode  Headcount  \
# Name
# #66#                                815393681   51100.0        0.0
# #CAP WELL CONSULTING               2152347376  304920.0        0.0
# #SCALENES                           797980877   75017.0        0.0
# #TERRITOIREDIGITAL                 1734224720  138680.0        0.0
# & + SI AFFINITES...                 488299546   59493.0        1.0
# ...                                       ...       ...        ...
# ZZM                                2377719744   12870.0        0.0
# ZZO                                1505105656       0.0        0.0
# ZZZ BELT                            801248238   92100.0        0.0
# [BOULANGER-LE DENMAT] ARCHITECTES   523778215       0.0        0.0
# [E]PURE                             808525471   63170.0        0.0
#
#                                    Fiscal_year_duration_in_months    Year
# Name
# #66#                                                         12.0  2016.0
# #CAP WELL CONSULTING                                         48.0  8058.0
# #SCALENES                                                    12.0  2014.0
# #TERRITOIREDIGITAL                                           48.0  8058.0
# & + SI AFFINITES...                                          12.0  2014.0
# ...                                                           ...     ...
# ZZM                                                          36.0  6045.0
# ZZO                                                          24.0  4029.0
# ZZZ BELT                                                     12.0  2016.0
# [BOULANGER-LE DENMAT] ARCHITECTES                            12.0  2013.0
# [E]PURE                                                      12.0  2017.0
#
# [528646 rows x 5 columns]

# %%
X_df['Activity_code (APE)'] = X_df['Activity_code (APE)'].fillna(value = '00').astype('str').apply(lambda x: x[:2])
# Out:
# 0          00
# 1          00
# 2          00
# 3          00
# 4          00
#            ..
# 1495943    18
# 1495944    28
# 1495945    28
# 1495946    28
# 1495947    28
# Name: Activity_code (APE), Length: 1495948, dtype: object

# %%
X_df['Fiscal_year_end_date'] = pd.to_datetime(X_df['Fiscal_year_end_date'], format='%Y-%m-%d')

# %%
X_df.shape
# Out:
# (1495948, 10)

# %%
# proportion of NaN values
X_df.isna().sum() / X_df.shape[0]
# Out:
# Legal_ID                          0.000000
# Name                              0.000002
# Activity_code (APE)               0.012293
# Address                           0.175296
# Zipcode                           0.167944
# City                              0.000313
# Headcount                         0.637439
# Fiscal_year_end_date              0.000000
# Fiscal_year_duration_in_months    0.000000
# Year                              0.000000
# dtype: float64

# %%
# number of unique values
X_df.nunique()
# Out:
# Legal_ID                          563929
# Name                              528646
# Activity_code (APE)                  964
# Address                           276152
# Zipcode                             7471
# City                               29498
# Headcount                           2224
# Fiscal_year_end_date                 300
# Fiscal_year_duration_in_months         1
# Year                                   6
# dtype: int64

# %%
X_df.dtypes
# Out:
# Legal_ID                                   int64
# Name                                      object
# Activity_code (APE)                       object
# Address                                   object
# Zipcode                                  float64
# City                                      object
# Headcount                                float64
# Fiscal_year_end_date              datetime64[ns]
# Fiscal_year_duration_in_months           float64
# Year                                     float64
# dtype: object

# %%
X_df.describe()
# Out:
#            Legal_ID       Zipcode     Headcount  \
# count  1.495948e+06  1.244713e+06  5.423720e+05
# mean   5.060829e+08  5.464419e+04  8.736985e+01
# std    1.417373e+08  2.755171e+04  9.002249e+03
# min    5.822960e+05  6.000000e+00 -3.900000e+01
# 25%    4.149439e+08  3.185000e+04  1.000000e+00
# 50%    4.895445e+08  6.053000e+04  3.000000e+00
# 75%    5.293306e+08  7.511600e+04  9.000000e+00
# max    9.999905e+08  9.889500e+04  5.450000e+06
#
#        Fiscal_year_duration_in_months          Year
# count                       1495948.0  1.495948e+06
# mean                             12.0  2.014475e+03
# std                               0.0  1.246598e+00
# min                              12.0  2.013000e+03
# 25%                              12.0  2.013000e+03
# 50%                              12.0  2.014000e+03
# 75%                              12.0  2.015000e+03
# max                              12.0  2.018000e+03

# %% [markdown]
# ### Distribution of Revenue

# %%
logRev = np.log10(np.clip(y_array, a_min=1, a_max=None))
seaborn.kdeplot(logRev)

# %% [markdown]
# ## Award notices

# %% [markdown]
# This dataset is present in the `data/` directory and is added by default to **all** submissions when submitting to RAMP studio. When testing your submission locally however, it is important to copy this file into the submission directory of the submission you wish to test.
#
# For example, the starting kit submission directory (`submissions/starting_kit`) contains a copy of this dataset as it is required for RAMP to work locally. You will not need to upload this data file when you are making a submission. See for more information.

# %%
award = pd.read_csv('data/award_notices_RAMP.csv.zip', compression='zip')
award.shape
# Out:
# (304098, 28)

# %%
award['Departments_of_publication'].isna().sum()
# Out:
# 5

# %%
award.dropna(subset = ['Total_amount', 'amount'], how = 'all')
# Out:
#            CallID     Publication_date End_of_call_date  \
# 0       16-119770  2016-08-11 00:00:00       2016-09-20
# 13      15-129814  2015-08-21 00:00:00       2015-10-20
# 14      15-129814  2015-08-21 00:00:00       2015-10-20
# 15      15-129814  2015-08-21 00:00:00       2015-10-20
# 16      14-178713  2015-04-23 00:00:00       2015-07-21
# ...           ...                  ...              ...
# 304093  18-182037           2018-12-31       2019-03-01
# 304094  18-181985           2018-12-31       2019-03-30
# 304095  18-181985           2018-12-31       2019-03-30
# 304096  18-181983           2018-12-31       2019-01-30
# 304097  18-181983           2018-12-31       2019-01-30
#
#        Departments_of_publication Departments_of_provision  \
# 0                              13                      NaN
# 13                             33                       33
# 14                             33                       33
# 15                             33                       33
# 16                              7                       07
# ...                           ...                      ...
# 304093                         61                      NaN
# 304094                         72                      NaN
# 304095                         72                      NaN
# 304096                         64                      NaN
# 304097                         64                      NaN
#
#                                              Call_summary  \
# 0       mission de maitrise d'oeuvre relative aux trav...
# 13      travaux d'assainissement et de chauffage urbai...
# 14      travaux d'assainissement et de chauffage urbai...
# 15      travaux d'assainissement et de chauffage urbai...
# 16      construction d'un immeuble de 18 logements loc...
# ...                                                   ...
# 304093  la présente consultation concerne la fournitur...
# 304094  Mise aux normes des bâtiments du Circuit des 2...
# 304095  Mise aux normes des bâtiments du Circuit des 2...
# 304096  Location de copieurs multifonctions avec contr...
# 304097  Location de copieurs multifonctions avec contr...
#
#                                                Call_title  \
# 0       MISSION DE MAITRISE D'OEUVRE RELATIVE AUX TRAV...
# 13      Travaux d'assainissement et de chauffage urbai...
# 14      Travaux d'assainissement et de chauffage urbai...
# 15      Travaux d'assainissement et de chauffage urbai...
# 16                                                    NaN
# ...                                                   ...
# 304093                                                NaN
# 304094                                                NaN
# 304095                                                NaN
# 304096                                                NaN
# 304097                                                NaN
#
#                                 Complete_call_description  Total_amount  \
# 0       MISSION DE MAITRISE D'OEUVRE RELATIVE AUX TRAV...           NaN
# 13      Travaux d'assainissement et de chauffage urbai...           NaN
# 14      Travaux d'assainissement et de chauffage urbai...           NaN
# 15      Travaux d'assainissement et de chauffage urbai...           NaN
# 16      Construction d'un immeuble de 18 logements loc...           NaN
# ...                                                   ...           ...
# 304093  La présente consultation concerne la fournitur...           NaN
# 304094  Mise aux normes des bâtiments du Circuit des 2...           NaN
# 304095  Mise aux normes des bâtiments du Circuit des 2...           NaN
# 304096  Location de copieurs multifonctions avec contr...           NaN
# 304097  Location de copieurs multifonctions avec contr...           NaN
#
#        CPV_classes  ...   ID awarded  \
# 0         71000000  ...  NaN     Yes
# 13        45232431  ...    1     Yes
# 14        45232431  ...    2     Yes
# 15        45232431  ...    3     Yes
# 16             NaN  ...   01     Yes
# ...            ...  ...  ...     ...
# 304093         NaN  ...    2     Yes
# 304094         NaN  ...    1     Yes
# 304095         NaN  ...    2     Yes
# 304096         NaN  ...    1     Yes
# 304097         NaN  ...    2     Yes
#
#                                               description  \
# 0                                                     NaN
# 13              Travaux sur poste de pompage Carle Vernet
# 14      Travaux de terrassement et pose du réseau d'as...
# 15      Travaux de terrassement partiel, de fourniture...
# 16                                           Désamiantage
# ...                                                   ...
# 304093  Fourniture et pose d'un sol amortissant pour l...
# 304094                              Serrurerie-Maçonnerie
# 304095                       Sols-Peintures-Signalétiques
# 304096                      Matériel pour la reprographie
# 304097                   Matériel pour le centre de santé
#
#                                            incumbent_name  \
# 0                                              AI PROJECT
# 13                                              SADE CGTH
# 14      Groupement Sade/Canalisations Souterraines/Cha...
# 15      Groupement solidaireSogea Sud-Ouest Hydrauliqu...
# 16                                       TBC DESAMIANTAGE
# ...                                                   ...
# 304093                           MULTI SERVICES NORMANDIE
# 304094                                            A.M.C.I
# 304095                                            A.M.C.I
# 304096                             Collectivites services
# 304097                             Collectivites services
#
#                     incumbent_address incumbent_zipcode incumbent_city  \
# 0          11, avenue de la Capelette             13010      Marseille
# 13      15 avenue Gustave Eiffel BP 3             33600         Pessac
# 14       15 avenue Gustave EiffelBP 3             33602   Pessac Cedex
# 15                3 rue Gaspard Monge             33606   Pessac Cedex
# 16             215 IMPASSE DES GAURES             26600  CHANOS CURSON
# ...                               ...               ...            ...
# 304093       Boulevard de l'Espérance           14903.0   Caen Cedex 9
# 304094    53 RUE SAINT ANDRE DE GELLY             72110     Bonnétable
# 304095    53 RUE SAINT ANDRE DE GELLY           72110.0     Bonnétable
# 304096                            NaN               NaN            NaN
# 304097                            NaN               NaN            NaN
#
#         incumbent_country number_of_received_bids      amount
# 0                      FR                    13.0    83200.00
# 13                     FR                     7.0   430400.05
# 14                     FR                     7.0  2642322.80
# 15                     FR                     7.0  3735254.61
# 16                     FR                     3.0    11080.00
# ...                   ...                     ...         ...
# 304093                 FR                     NaN    25952.13
# 304094                 FR                     NaN    35968.84
# 304095                 FR                     NaN    19209.32
# 304096                 FR                     NaN     6725.00
# 304097                 FR                     NaN      534.00
#
# [223465 rows x 28 columns]

# %%
award.dtypes
# Out:
# CallID                         object
# Publication_date               object
# End_of_call_date               object
# Departments_of_publication     object
# Departments_of_provision       object
# Call_summary                   object
# Call_title                     object
# Complete_call_description      object
# Total_amount                  float64
# CPV_classes                    object
# Buyer_name                     object
# Buyer_address                  object
# Buyer_zipcode                  object
# Buyer_city                     object
# Buyer_email                    object
# Buyer_URL                      object
# Contract_awarded               object
# Lot                             int64
# ID                             object
# awarded                        object
# description                    object
# incumbent_name                 object
# incumbent_address              object
# incumbent_zipcode              object
# incumbent_city                 object
# incumbent_country              object
# number_of_received_bids       float64
# amount                        float64
# dtype: object

# %%
award.describe()
# Out:
#        Total_amount            Lot  number_of_received_bids        amount
# count  1.121260e+05  304098.000000            220936.000000  2.159540e+05
# mean   5.177948e+08       2.073213                 4.606900  1.145206e+08
# std    6.712391e+10       1.293831                 7.982825  2.288319e+10
# min    9.900000e-05       1.000000                 0.000000  0.000000e+00
# 25%    1.967891e+05       1.000000                 2.000000  3.240000e+04
# 50%    4.821163e+05       2.000000                 3.000000  1.159775e+05
# 75%    1.568197e+06       3.000000                 5.000000  3.674995e+05
# max    1.000000e+13       5.000000               727.000000  1.000000e+13

# %%
# proportion of NA values
award.isna().sum() / award.shape[0]
# Out:
# CallID                        0.000016
# Publication_date              0.000016
# End_of_call_date              0.000510
# Departments_of_publication    0.000016
# Departments_of_provision      0.674611
# Call_summary                  0.000016
# Call_title                    0.346484
# Complete_call_description     0.005426
# Total_amount                  0.631283
# CPV_classes                   0.082602
# Buyer_name                    0.000016
# Buyer_address                 0.017484
# Buyer_zipcode                 0.024084
# Buyer_city                    0.000016
# Buyer_email                   0.163766
# Buyer_URL                     0.211047
# Contract_awarded              0.000016
# Lot                           0.000000
# ID                            0.271015
# awarded                       0.034907
# description                   0.512683
# incumbent_name                0.034943
# incumbent_address             0.140126
# incumbent_zipcode             0.103414
# incumbent_city                0.061280
# incumbent_country             0.034943
# number_of_received_bids       0.273471
# amount                        0.289854
# dtype: float64

# %% [markdown]
# # Predictions

# %% [markdown]
# ## Company revenue only
#
# First, let's predict using only the `comp` dataset:

# %% [markdown]
# 1. Create a transformer that deals with missing values:

# %%
X_df.dtypes
# Out:
# Legal_ID                                   int64
# Name                                      object
# Activity_code (APE)                       object
# Address                                   object
# Zipcode                                  float64
# City                                      object
# Headcount                                float64
# Fiscal_year_end_date              datetime64[ns]
# Fiscal_year_duration_in_months           float64
# Year                                     float64
# dtype: object

# %%
# list of numerical columns
num_cols = ['Legal_ID', 'Headcount', 'Fiscal_year_duration_in_months', 'Year']

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

numeric_transformer = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='median'))
])

# %% [markdown]
# 2. Create a transformer to split `Fiscal_year_end_date` into separate year, month, day columns:

# %%
from sklearn.preprocessing import FunctionTransformer

def process_date(X):
    date = pd.to_datetime(X['Fiscal_year_end_date'], format='%Y-%m-%d')
    return np.c_[date.dt.year, date.dt.month, date.dt.day]

date_transformer = FunctionTransformer(process_date, validate=False)

# %% [markdown]
# 3. Process the `Activity_code (APE)` column. At the moment the Scikit learn `OrdinalEncoder()` does not have a `handle_unknown` argument. This means that it would not be able to handle any values in `Activity_code (APE)` which appear in 'train' but do not appear in 'test'. Here we will simply get around this by using the first 2 characters of `APE`, which are always numbers. The first 2 numbers give the broad category the companies activities fall under (e.g. 'AGRICULTURE'). This column is then converted to numeric data type, so missing values can be dealt with by using the median value (with `SimpleImputer()`).

# %%
def process_APE(X):
    APE = X['Activity_code (APE)'].str[:2]
    return pd.to_numeric(APE, errors='coerce').values[:, np.newaxis]

APE_transformer = FunctionTransformer(process_APE, validate=False)

# %% [markdown]
# 4. Only keep the numbers in the `Zipcode` column:

# %%
def zipcodes(X):
    zipcode_nums = pd.to_numeric(X['Zipcode'], errors='coerce')
    return zipcode_nums.values[:, np.newaxis]

zipcode_transformer = FunctionTransformer(zipcodes, validate=False)

# %% [markdown]
# Finally the full pipeline is assembled.
#
# * for missing values in numerical columns, the 'median' is used.
# * the date column `Fiscal_year_end_date` is transformed into separated year month and day columns.
# * `Activity_code (APE)` is dealt with as described above.
# * the columns `Name`, `Address` and `City` are all dropped.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

zipcode_col = ['Zipcode']
date_cols = ['Fiscal_year_end_date']
drop_cols = ['Name', 'Address', 'City']
APE_col = ['Activity_code (APE)']


preprocessor_comp = ColumnTransformer(
    transformers=[
        ('zipcode', make_pipeline(zipcode_transformer, SimpleImputer(strategy='median')), zipcode_col),
        ('num', numeric_transformer, num_cols),
        ('date', make_pipeline(date_transformer, SimpleImputer(strategy='median')), date_cols),
        ('APE', make_pipeline(APE_transformer, SimpleImputer(strategy='median')), APE_col),
        ('drop cols', 'drop', drop_cols),
    ])

# %%
# make sure it works
preprocessor_comp.fit_transform(X_df)
# Out:
# array([[6.05300000e+04, 5.82296000e+05, 3.00000000e+00, ...,
#         1.20000000e+01, 3.10000000e+01, 4.90000000e+01],
#        [6.05300000e+04, 5.82981000e+05, 3.00000000e+00, ...,
#         1.20000000e+01, 3.10000000e+01, 4.90000000e+01],
#        [9.88000000e+04, 5.88541000e+05, 1.00000000e+00, ...,
#         1.20000000e+01, 3.10000000e+01, 4.90000000e+01],
#        ...,
#        [6.05300000e+04, 9.95750288e+08, 3.00000000e+00, ...,
#         1.00000000e+00, 3.10000000e+01, 2.80000000e+01],
#        [6.05300000e+04, 9.95750288e+08, 3.84000000e+02, ...,
#         1.20000000e+01, 3.10000000e+01, 2.80000000e+01],
#        [6.05300000e+04, 9.95750288e+08, 3.72000000e+02, ...,
#         1.20000000e+01, 3.10000000e+01, 2.80000000e+01]])

# %% [markdown]
# We will use a Random Forest Regressor model:

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=10)

# %% [markdown]
# Before we can test our model, we need to define our unique scoring function:

# %%
from sklearn.metrics import make_scorer

def loss(y_true, y_pred):
    
    if isinstance(y_true, pd.Series):
        y_true = y_true.values

    true = np.maximum(5., np.log10(np.maximum(1., y_true)))
    pred = np.maximum(5., np.log10(np.maximum(1., y_pred)))
    
    loss = np.mean(np.abs(true - pred))
    
    return loss
    
fan_loss = make_scorer(loss, greater_is_better=False)

# %% [markdown]
# Now we can test our model. Note that we use `GroupShuffleSplit` using `Legal_ID` as the group so that the same company ('Legal_ID') only appears in either 'train' or 'test' but does not appear both in 'train' **and** 'test'.
#
# This reflects the same conditions of this challenge where, the private 'test' data (on RAMP) does not contain any company that also appears in the public 'train' dataset you have access to. This is because `Revenue` for the same company is often very similar.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GroupShuffleSplit

clf = Pipeline(steps=[
    ('preprocessing', preprocessor_comp),
    ('classifier', regressor)])

cv = GroupShuffleSplit(n_splits=8, test_size=0.25)

scores_Xdf = -cross_val_score(clf, X_df, y_array, cv=cv, scoring=fan_loss, groups=X_df['Legal_ID'], n_jobs=2)

print("mean: %e (+/- %e)" % (scores_Xdf.mean(), scores_Xdf.std()))

# %% [markdown]
# ## Naive merge
#
# Now let us predict using a naive merge of `award` and `comp` datasets.
#
# The naive merge will only use the name of the company. To aid the merging we will convert the name to all lower case and remove punctuation and white space.

# %%
award['Name_processed'] = award['incumbent_name'].str.lower()
award['Name_processed'] = award['Name_processed'].str.replace('[^\w]','')

# %% [markdown]
# For each company, extract 2 features:
#
# * the number of award lots won
# * the total sum of award lots won

# %%
award_features = award.groupby(['Name_processed'])['amount'].agg(['count','sum'])
award_features.head(3)
# Out:
#                 count       sum
# Name_processed
#                     1  55479.36
# 0                   1      0.00
# 00000               0      0.00

# %% [markdown]
# Next we will perform a naive merge of `X_df` and `award_features`.
#
# Be careful in this step to ensure that the **order** of `X_df` is not changed.

# %%
from sklearn.preprocessing import FunctionTransformer
def merge_naive(X):
    X['Name'] = X['Name'].str.lower()     
    X['Name'] = X['Name'].str.replace('[^\w]','')
    df = pd.merge(X, award_features, left_on='Name', right_on='Name_processed', how='left')
    return df[['count','sum']]
merge_transformer = FunctionTransformer(merge_naive, validate=False)

# %% [markdown]
# Implement the same feature transformation steps as above and include the 'merge' step.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

zipcode_col = ['Zipcode']
date_cols = ['Fiscal_year_end_date']
drop_cols = ['Address', 'City']
APE_col = ['Activity_code (APE)']
merge_col = ['Name']

preprocessor_merge = ColumnTransformer(
    transformers=[
        ('zipcode', make_pipeline(zipcode_transformer, SimpleImputer(strategy='median')), zipcode_col),
        ('num', numeric_transformer, num_cols),
        ('date', make_pipeline(date_transformer, SimpleImputer(strategy='median')), date_cols),
        ('APE', make_pipeline(APE_transformer, SimpleImputer(strategy='median')), APE_col),
        ('merge', make_pipeline(merge_transformer, SimpleImputer(strategy='median')), merge_col),
        ('drop cols', 'drop', drop_cols),
    ])

# %%
# check it works
preprocessor_merge.fit_transform(X_df).shape
# Out:
# (1495948, 11)

# %% [markdown]
# This example is implemented in RAMP within the files in the folder `submissions/starting_kit`.
#
# The transformation steps above are implemented in the file `submissions/starting_kit/feature_extractor.py` (a copy of this file is shown below). This file needs to define a class called `FeatureExtractor` which requires a `fit()` and `transform()` function. The `fit()` function takes both `X_df` and `y_array` as parameters, meaning that you are able to engineer new features using `y_array` (e.g. target encoding). The `transform()` function only takes `X_df`. We only use the `transform()` function in our simple example below.
#
# Note that the `award` dataset is being read in from the submission folder (`submissions/starting_kit`). This means that when testing locally, each submission folder should contain a copy of the award dataset `award_notices_RAMP.csv`.

# %%
import os
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline


class FeatureExtractor(object):
    def __init__(self):
        pass

    def fit(self, X_df, y_array):
        pass

    def transform(self, X_df):
        X_encoded = X_df

        path = os.path.dirname(__file__)
        award = pd.read_csv(os.path.join(path, 'award_notices_RAMP.csv.zip', compression='zip'),
                            low_memory=False)
        # obtain features from award
        award['Name_processed'] = award['incumbent_name'].str.lower()
        award['Name_processed'] = award['Name_processed'].str.replace('[^\w]','')
        award_features = award.groupby(['Name_processed'])['amount'].agg(['count','sum'])

        def zipcodes(X):
            zipcode_nums = pd.to_numeric(X['Zipcode'], errors='coerce')
            return zipcode_nums.values[:, np.newaxis]
        zipcode_transformer = FunctionTransformer(zipcodes, validate=False)

        numeric_transformer = Pipeline(steps=[
            ('impute', SimpleImputer(strategy='median'))])

        def process_date(X):
            date = pd.to_datetime(X['Fiscal_year_end_date'], format='%Y-%m-%d')
            return np.c_[date.dt.year, date.dt.month, date.dt.day]
        date_transformer = FunctionTransformer(process_date, validate=False)
        
        def process_APE(X):
            APE = X['Activity_code (APE)'].str[:2]
            return pd.to_numeric(APE).values[:, np.newaxis]
        APE_transformer = FunctionTransformer(process_APE, validate=False)

        def merge_naive(X):
            X['Name'] = X['Name'].str.lower()     
            X['Name'] = X['Name'].str.replace('[^\w]','')
            df = pd.merge(X, award_features, left_on='Name', 
                          right_on='Name_processed', how='left')
            return df[['count','sum']]
        merge_transformer = FunctionTransformer(merge_naive, validate=False)

        num_cols = ['Legal_ID', 'Headcount', 
                    'Fiscal_year_duration_in_months', 'Year']
        zipcode_col = ['Zipcode']
        date_cols = ['Fiscal_year_end_date']
        APE_col = ['Activity_code (APE)']
        merge_col = ['Name']
        drop_cols = ['Address', 'City']

        preprocessor = ColumnTransformer(
            transformers=[
                ('zipcode', make_pipeline(zipcode_transformer, SimpleImputer(strategy='median')), zipcode_col),
                ('num', numeric_transformer, num_cols),
                ('date', make_pipeline(date_transformer, SimpleImputer(strategy='median')), date_cols),
                ('APE', make_pipeline(APE_transformer, SimpleImputer(strategy='median')), APE_col),
                ('merge', make_pipeline(merge_transformer, SimpleImputer(strategy='median')), merge_col),
                ('drop cols', 'drop', drop_cols),
                ])

        X_array = preprocessor.fit_transform(X_encoded)
        return X_array

# %% [markdown]
# We will use a Random Forest Regressor model again:

# %%
regressor = RandomForestRegressor(n_estimators=10)

# %% [markdown]
# This is implemented in the file `submissions/starting_kit/regressor.py` (a copy of this file is shown below). The `Regressor` class must have a `fit()` and `predict()` function. If you are using a scikit-learn function, this can be done by simply calling `fit()` and `predict()` on the regressor, as seen below.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import BaseEstimator


class Regressor(BaseEstimator):
    def __init__(self):
        self.reg = RandomForestRegressor(n_estimators=5)

    def fit(self, X, y):
        self.reg.fit(X, y)

    def predict(self, X):
        return self.reg.predict(X)

# %% [markdown]
# We can test our model within this notebook, using `preprocessor_merge` and `regressor` defined above, in a `Pipeline()`.
#
# Once you are happy with a solution, you can transfer your solution to `feature_extractor.py` and `regressor.py` files and test your submission using RAMP (see 'Submissions').

# %%
clf = Pipeline(steps=[
    ('preprocessing', preprocessor_merge),
    ('classifier', regressor)])

cv = GroupShuffleSplit(n_splits=8, test_size=0.25)

scores_merge = -cross_val_score(clf, X_df, y_array, cv=cv, scoring=fan_loss, groups=X_df['Legal_ID'],
                               n_jobs=2)

print("mean: %e (+/- %e)" % (scores_merge.mean(), scores_merge.std()))

# %% [markdown]
# ## Score comparison
#
# You can see in the below plot of the scores that using the merged data always results in better scores (smaller is better):

# %%
scores = pd.DataFrame({'Xdf': scores_Xdf, 'merge': scores_merge})
scores.boxplot()

# %% [markdown]
# # Record linkage
#
# The problem of trying to match 'records' referring to the same entity across different data sources is called  record linkage. We used a very naive way to match companies above but there are much more sophiisticated methods and packages implementing these methods. To get you started here are two Python packages:
#
# * [Python Record Linkage Toolkit](https://recordlinkage.readthedocs.io/en/latest/index.html)
# * [Dedupe](https://github.com/dedupeio/dedupe)

# %% [markdown]
# # Submission structure
#
# Each of your submissions should be in it's own folder within the `submissions` folder (e.g. `submissions/my_submission`). The submission directory should contain 3 files:
#
# * a copy of the `award_notices_RAMP.csv` dataset. Note that you will **not** need to upload this file when making a submission in RAMP studio as this is done automatically by RAMP studio.
# * `feature_extractor.py` - this should merge the `X_df` and the award dataset and any feature transformation you wish
# * `regressor.py` - this should implement a regressor with a `fit()` and `predict()` function
#
# See `submissions/starting_kit` for an example.
#
# You can also test your submissions using RAMP-workflow before submitting:

# %% [markdown]
# ## Local testing (before submission)
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. For this we provide a unit test - `ramp_test_submission`.
#
# First, ensure that `ramp-worflow` is installed (see the [github repo](https://github.com/paris-saclay-cds/ramp-workflow) for installation instructions).
#
# Now you can use `ramp_test_submission`. This command will test on files in [`submissions/starting_kit`](/submissions/starting_kit) by default. To specify testing on a different folder use the flag `--submission`. For example to run the test on `submissions/solution1` use: `ramp_test_submission --submission solution1`.
#
# If it runs and print training and test errors on each fold, then you can submit the code.
#
# For example, below we test the starting kit:

# %%
# !ramp_test_submission

# %% [markdown]
# ## Submitting to [ramp.studio](http://ramp.studio)
#
# Once you found a good model, you can submit it to [ramp.studio](http://www.ramp.studio). First, if it is your first time using RAMP, [sign up](http://www.ramp.studio/sign_up), otherwise [log in](http://www.ramp.studio/login). Then sign up for the 'FAN_revenue_prediction' challenge and the 'Saclay M2 Data Camp 2019/20' [event](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19). Both signups are controlled by RAMP administrators, so there **can be a delay between asking for signup and being able to submit**.
#
# Once your signup request is accepted, you can go to your [sandbox](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19/sandbox). Here you can either edit and save the code files on the left hand side of the page or upload your `feature_extractor.py` and `regressor.py` files on the right hand side of the page, then give your submission a name and click 'submit'. The submission is trained and tested on our backend in the same way as `ramp_test_submission` does it locally. While your submission is waiting in the queue and being trained, you can find it in the "New submissions (pending training)" table in [my submissions](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19/my_submissions). Once it is trained, you get an email, and your submission shows up on the [public leaderboard](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19/leaderboard).
# If there is an error (despite having tested your submission locally with `ramp_test_submission`), it will show up in the "Failed submissions" table in [my submissions](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19/my_submissions). You can click on the error to see part of the trace.
#
# After submission, do not forget to give credits to the previous submissions you reused or integrated into your submission.
#
# The data set we use at the backend is usually different from what you find in the starting kit, so the score may be different.
#
# The usual way to work with RAMP is to explore solutions, add feature transformations, select models, perhaps do some AutoML/hyperopt, etc., _locally_ then check that your submission works locally with `ramp_test_submission`. The script will print mean cross-validation scores if your submission works.
#
# The official score in this RAMP (the first score column after "historical contributivity" on the [leaderboard](https://ramp.studio/events/fan_revenue_prediction_saclay_datacamp_19/leaderboard)) is `FAN error`.

# %% [markdown]
# ## More information
#
# You can find more information in the [README](https://github.com/paris-saclay-cds/ramp-workflow/blob/master/README.md) of the [ramp-workflow library](https://github.com/paris-saclay-cds/ramp-workflow).
